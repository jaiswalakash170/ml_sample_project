# %%
import pandas as pd

# %% [markdown]
# ## Two important data types

# %% [markdown]
# # 1. Series

# %%
series = pd.Series(["BMW", "Toyoto", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyoto
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# # 2. Data Frames

# %%
car_data = pd.DataFrame({"Car Make": series, "Colour": colours})

# %%
car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyoto   Blue
# 2    Honda  White

# %% [markdown]
# Import Data - CSV

# %%
heart_desease_data = pd.read_csv("heart-disease.csv")

# %%
heart_desease_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_desease_data.to_csv("exported-heart-desease.csv", index=False)

# %%
exported_heart_desease_data = pd.read_csv("exported-heart-desease.csv")

# %%
exported_heart_desease_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # Describe Data

# %%
heart_desease_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_desease_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_desease_data_columns = heart_desease_data.columns

# %%
heart_desease_data_columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_desease_data.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
heart_desease_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_desease_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_desease_data.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])

# %%
car_prices.mean()
# Out:
# 38583.333333333336

# %%
heart_desease_data.sum()
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
heart_desease_data["age"].sum()
# Out:
# 16473

# %%
len(heart_desease_data)
# Out:
# 303

# %% [markdown]
# # Selecting & Viewing Data

# %%
heart_desease_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_desease_data.head(15)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
heart_desease_data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart_desease_data.tail(20)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 283   40    1   0       152   223    0        1      181      0      0.0
# 284   61    1   0       140   207    0        0      138      1      1.9
# 285   46    1   0       140   311    0        1      120      1      1.8
# 286   59    1   3       134   204    0        1      162      0      0.8
# 287   57    1   1       154   232    0        0      164      0      0.0
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# ...

# %%
heart_desease_data.tail(305)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # loc & iloc Functions

# %%
animals = pd.Series(["Cat", "Dog", "Bird", "Panda", "Snake"], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      Cat
# 3      Dog
# 9     Bird
# 8    Panda
# 3    Snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'Bird'

# %%
heart_desease_data.loc[156]
# Out:
# age          47.0
# sex           1.0
# cp            2.0
# trestbps    130.0
# chol        253.0
# fbs           0.0
# restecg       1.0
# thalach     179.0
# exang         0.0
# oldpeak       0.0
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 156, dtype: float64

# %%
car_data.loc[2]
# Out:
# Car Make    Honda
# Colour      White
# Name: 2, dtype: object

# %%
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_data.iloc[2]
# Out:
# Car Make    Honda
# Colour      White
# Name: 2, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     Cat
# 3     Dog
# 9    Bird
# dtype: object

# %%
animals.iloc[1:3]
# Out:
# 3     Dog
# 9    Bird
# dtype: object

# %%
animals.iloc[::-1]
# Out:
# 3    Snake
# 8    Panda
# 9     Bird
# 3      Dog
# 0      Cat
# dtype: object

# %%
car_data["Car Make"]
# Out:
# 0       BMW
# 1    Toyoto
# 2     Honda
# Name: Car Make, dtype: object

# %%
car_data.Colour
# Out:
# 0      Red
# 1     Blue
# 2    White
# Name: Colour, dtype: object

# %%
heart_desease_data[heart_desease_data["age"] > 35]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
car_data[car_data["Colour"] == "White"]
# Out:
#   Car Make Colour
# 2    Honda  White

# %%
car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyoto   Blue
# 2    Honda  White

# %%
pd.crosstab(car_data["Car Make"], car_data["Colour"])
# Out:
# Colour    Blue  Red  White
# Car Make
# BMW          0    1      0
# Honda        0    0      1
# Toyoto       1    0      0

# %% [markdown]
# # Group By

# %%
heart_desease_data.groupby(["age"]).mean()
# Out:
#           sex        cp    trestbps        chol       fbs   restecg  \
# age
# 29   1.000000  1.000000  130.000000  204.000000  0.000000  0.000000
# 34   0.500000  2.000000  118.000000  196.000000  0.000000  0.500000
# 35   0.750000  0.250000  126.500000  213.750000  0.000000  0.750000
# 37   0.500000  2.000000  125.000000  232.500000  0.000000  1.000000
# 38   1.000000  2.333333  132.000000  193.666667  0.000000  1.000000
# 39   0.500000  1.500000  122.500000  239.750000  0.000000  0.750000
# 40   1.000000  1.000000  134.000000  196.333333  0.000000  0.666667
# 41   0.600000  1.200000  119.000000  220.700000  0.000000  0.600000
# 42   0.750000  1.250000  127.000000  246.750000  0.125000  0.750000
# 43   0.750000  0.500000  126.375000  256.750000  0.250000  0.625000
# 44   0.818182  1.181818  120.727273  221.363636  0.000000  0.636364
# 45   0.625000  0.750000  122.375000  247.375000  0.000000  0.250000
# 46   0.571429  0.857143  128.000000  230.285714  0.142857  0.571429
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
heart_desease_data["age"].plot()
# Out:
# <AxesSubplot:>

# %%
heart_desease_data["age"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]', '').astype(float)
# Out:
# <ipython-input-88-e7b62aeaf399>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]', '').astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulate Data with Padas

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped-data.csv")

# %% [markdown]
# # Column from series

# %%
seats_column = pd.Series([5,5,5,5,5])

# %%
seats_column
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(4, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    4.0
# 6   honda   Blue          45698      4   7500.0    4.0
# 7   honda   Blue          54738      4   7000.0    4.0
# 8  toyota  White          60000      4   6250.0    4.0
# 9  nissan  White          31600      4   9700.0    4.0

# %%
fule_economy = [7.5, 9.2, 5.6, 7.2, 4.9, 8.7, 3.0, 9.9, 10.0, 1.2]

# %%
fule_economy
# Out:
# [7.5, 9.2, 5.6, 7.2, 4.9, 8.7, 3.0, 9.9, 10.0, 1.2]

# %%
car_sales["Fuel Per 100Km"] = fule_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100Km"]

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100Km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Total Fuel Used
# 0        11253.225
# 1         8086.708
# 2         1822.744
# 3          804.888
# 4        10441.655
# 5         8631.531
# 6         1370.940
# 7         5419.062
# ...

# %%
car_sales["Number of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Total Fuel Used  Number of Wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1822.744                 4
# ...

# %%
car_sales["Passed Road Safety"] = True

# %%
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                 float64
# Seats                 float64
# Fuel Per 100Km        float64
# Total Fuel Used       float64
# Number of Wheels        int64
# Passed Road Safety       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety  Total Fuel Used (L)
# 0        11253.225                 4                True            11253.225
# ...

# %%
car_sales.drop("Total Fuel Used", axis = 1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)
# 0                 4                True            11253.225
# 1                 4                True             8086.708
# ...

# %%
car_type = ['SUV', 'Sport', 'Sedan', 'Hatchback', 'Compact SUV', 'SUV', 'Van', 'Sport', 'Hatchback', 'Compact SUV']

# %%
car_type
# Out:
# ['SUV',
#  'Sport',
#  'Sedan',
#  'Hatchback',
#  'Compact SUV',
#  'SUV',
#  'Van',
#  'Sport',
#  'Hatchback',
#  'Compact SUV']

# %%
car_sales["Car Type"] = car_type

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)     Car Type
# 0                 4                True            11253.225          SUV
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9  nissan  White          31600      4   9700.0    4.0             1.2
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)     Car Type
# 0                 4                True            11253.225          SUV
# ...

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 9  nissan  White          31600      4   9700.0    4.0             1.2
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 5  toyota  Green          99213      4   4500.0    4.0             8.7
# 6   honda   Blue          45698      4   7500.0    4.0             3.0
# 4  nissan  White         213095      4   3500.0    5.0             4.9
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 3     bmw  Black          11179      5  22000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 7   honda   Blue          54738      4   7000.0    4.0             9.9
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)     Car Type
# 9                 4                True              379.200  Compact SUV
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  nissan  White          31600      4   9700.0    4.0             1.2
# 1  toyota  White         150043      4   4000.0    5.0             7.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.6
# 3  toyota  Green          99213      4   4500.0    4.0             8.7
# 4   honda   Blue          45698      4   7500.0    4.0             3.0
# 5  nissan  White         213095      4   3500.0    5.0             4.9
# 6   honda    Red          87899      4   5000.0    5.0             9.2
# 7     bmw  Black          11179      5  22000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    4.0            10.0
# 9   honda   Blue          54738      4   7000.0    4.0             9.9
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)     Car Type
# 0                 4                True              379.200  Compact SUV
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel Per 100Km  \
# 0  toyota  White      93776.875      4   4000.0    5.0             7.5
# 1   honda    Red      54936.875      4   5000.0    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000.0    5.0             5.6
# 3     bmw  Black       6986.875      5  22000.0    5.0             7.2
# 4  nissan  White     133184.375      4   3500.0    5.0             4.9
# 5  toyota  Green      62008.125      4   4500.0    4.0             8.7
# 6   honda   Blue      28561.250      4   7500.0    4.0             3.0
# 7   honda   Blue      34211.250      4   7000.0    4.0             9.9
# 8  toyota  White      37500.000      4   6250.0    4.0            10.0
# 9  nissan  White      19750.000      4   9700.0    4.0             1.2
#
#    Number of Wheels  Passed Road Safety  Total Fuel Used (L)     Car Type
# 0                 4                True            11253.225          SUV
# ...
